# %% [markdown]
# 1. In the below elements which of them are values or an expression? eg:- values can be integer or string and expressions will be mathematical operators.
# *
# 'hello'
# -87.8
# -
# /
#
#
# 6

# %% [markdown]
# ANS= "hello" , 87.8 and 6 are the values whereas ( * , - , / , + ) are the expressions.

# %% [markdown]
# 2. What is the difference between string and variable?

# %% [markdown]
# ANS= " strings can print same values present or written in it and represented by { "    ", '   ',  """  """ } like this whereas variables are any value of alphabet which holds some numeric values in it like (x=10).

# %% [markdown]
# 3. Describe three different data types.

# %% [markdown]
# ANS= data types are as follows:
#  1} Integer data type=
# The integer data type in python consist the numbers that doesn't contain decimal point in it that are integers.
# ex.

# %%
a=7777
type(a)
# Out:
# int

# %% [markdown]
# 2} float data type=
# The float data type consist the numbers that contain decimal points in it that are floats. ex.

# %%
x=2.0
type(x)
# Out:
# float

# %% [markdown]
# 3} complex data type=
# The complex data type in pyhon consist of two values, the first one is the real part of complex number and the second part is imaginary whereas we usually denotes real part with i and imaginary part with "j"
# ex.

# %%
i=2+3j
type(i)
# Out:
# complex

# %% [markdown]
# 4. What is an expression made up of? What do all expressions do?

# %% [markdown]
# ANS= An expression is a combination of values and operators.All expressions evaluate(that is,reduce) to a single value.

# %% [markdown]
# 5. This assignment statements, like spam = 10. What is the difference between an expression and a statement?

# %% [markdown]
# ANS=  An expression evaluate to a single value whereas a statement does not.

# %% [markdown]
# 6. After running the following code, what does the variable bacon contain?
# bacon = 22
# bacon + 1

# %% [markdown]
# ANS= The bacon variable is set to 20.The bacon=1 expression does not reassign the value in bacon(that would need an assignment statement:bacon=bacon+1)

# %% [markdown]
# 7. What should the values of the following two terms be?
# 'spam' + 'spamspam'
# 'spam' * 3

# %% [markdown]
# ANS= Both expressons evaluate tp the string.

# %%
'spam'+'spamspam'
# Out:
# 'spamspamspam'

# %%
'spam'*3
# Out:
# 'spamspamspam'

# %% [markdown]
# 8. Why is eggs a valid variable name while 100 is invalid?

# %% [markdown]
# ANS= eggs is a valid variable name while 100 is invalid because a variable name must start with a letter or the underscore character whereas a variable name can only contain alpha-numeric characters and underscores(A-z,0-9,and_), variable names are case-sensitive and cannot start with a number.

# %% [markdown]
# 9. What three functions can be used to get the integer, floating-point number, or string version of a value?

# %% [markdown]
# ANS= The int(), float() and str() functions will evaluate to the integer, floating-point number, and string versions of the value passed to them.

# %% [markdown]
# 10. Why does this expression cause an error? How can you fix it?
# 'I have eaten ' + 99 + ' burritos.'

# %% [markdown]
# ANS= This expression can cause an error because 99 is an integer and only string concatinate to other string not "integer" to string.

# %%
'I have eaten' + str(99) + 'burritos'
# Out:
# 'I have eaten99burritos'
